# %%
import numpy as np
from sennet.core.mmap_arrays import read_mmap_array
import matplotlib.pyplot as plt

# read labels
file_path = "/opt/kaggle/sennet/data_dumps/processed/kidney_1_dense/image"
img = read_mmap_array(file_path)

print(f"{img.shape=}")
x = np.array(img.data.data).flatten()

# calculate percentile 1 and 99
p1 = np.percentile(x, 1)
p99 = np.percentile(x, 99)

# put vertical lines on the plot
plt.axvline(p1, color='r', linestyle='dashed', linewidth=2)
plt.axvline(p99, color='r', linestyle='dashed', linewidth=2)

plt.hist(x, bins=100)
# Out:
# img.shape=[2279, 1303, 912]
# (array([4.54680000e+04, 3.02700000e+03, 1.70700000e+03, 2.44100000e+03,
#         1.63400000e+03, 2.52600000e+03, 1.79500000e+03, 2.96900000e+03,
#         2.24200000e+03, 3.69100000e+03, 3.90000000e+03, 2.81400000e+03,
#         4.48200000e+03, 3.31400000e+03, 5.70600000e+03, 7.53900000e+03,
#         6.34149000e+05, 4.78023000e+05, 5.32930000e+04, 1.05690000e+04,
#         3.10280000e+04, 2.74890000e+04, 1.32850000e+04, 2.38690000e+04,
#         1.93440000e+04, 3.67840000e+04, 3.30450000e+04, 7.40130000e+04,
#         1.90593000e+05, 4.45621880e+07, 3.86826657e+08, 3.60212242e+08,
#         4.62392064e+08, 2.16947702e+08, 1.42079408e+08, 2.98258840e+07,
#         3.00194650e+07, 4.63510700e+07, 1.76779987e+08, 1.73085484e+08,
#         3.14857853e+08, 2.29948792e+08, 5.53601860e+07, 2.45810350e+07,
#         5.75267500e+06, 4.09304900e+06, 1.26876100e+06, 8.64772000e+05,
#         2.27515000e+05, 1.48675000e+05, 6.03410000e+04, 2.19680000e+04,
# ...

# %%
import numpy as np
from sennet.core.mmap_arrays import read_mmap_array
import matplotlib.pyplot as plt

# read labels
file_path = "/opt/kaggle/sennet/data_dumps/processed/kidney_2/image"
img = read_mmap_array(file_path)

print(f"{img.shape=}")
x = np.array(img.data.data).flatten()

# calculate percentile 1 and 99
p1 = np.percentile(x, 1)
p99 = np.percentile(x, 99)

# put vertical lines on the plot
plt.axvline(p1, color='r', linestyle='dashed', linewidth=2)
plt.axvline(p99, color='r', linestyle='dashed', linewidth=2)

plt.hist(x, bins=100)
# Out:
# img.shape=[2217, 1041, 1511]
# (array([1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#         2.00000000e+00, 2.00000000e+00, 3.00000000e+00, 5.00000000e+00,
#         4.00000000e+00, 4.00000000e+00, 3.00000000e+00, 7.00000000e+00,
#         1.40000000e+01, 6.79300000e+03, 4.26519000e+05, 6.45484000e+05,
#         6.65621000e+05, 5.16030000e+05, 7.35144000e+05, 1.33417000e+05,
#         1.64410000e+04, 6.17000000e+02, 6.10000000e+01, 8.00000000e+01,
#         7.00000000e+01, 1.37000000e+02, 1.09000000e+02, 1.88000000e+02,
#         1.70000000e+02, 1.89000000e+02, 3.93000000e+02, 4.15000000e+02,
#         3.70400000e+03, 9.38490000e+04, 4.89793900e+06, 2.18394730e+07,
#         8.74738140e+07, 8.83460560e+07, 1.17990004e+08, 2.72744547e+08,
#         2.47868001e+08, 4.07351955e+08, 2.73940168e+08, 4.54982665e+08,
#         2.67213483e+08, 2.35527950e+08, 2.88306070e+08, 1.53061962e+08,
# ...

# %%
import numpy as np
from sennet.core.mmap_arrays import read_mmap_array
import matplotlib.pyplot as plt

# read labels
file_path = "/opt/kaggle/sennet/data_dumps/processed/kidney_3_dense/image"
img = read_mmap_array(file_path)

print(f"{img.shape=}")
x = np.array(img.data.data).flatten()

# calculate percentile 1 and 99
p1 = np.percentile(x, 1)
p99 = np.percentile(x, 99)

# put vertical lines on the plot
plt.axvline(p1, color='r', linestyle='dashed', linewidth=2)
plt.axvline(p99, color='r', linestyle='dashed', linewidth=2)

plt.hist(x, bins=100)
# Out:
# img.shape=[501, 1706, 1510]
# (array([1.40000000e+01, 2.80000000e+01, 7.20000000e+01, 1.92300000e+03,
#         4.87500000e+03, 7.61200000e+03, 1.07810000e+04, 2.37560000e+04,
#         2.11600000e+04, 2.61050000e+04, 2.95270000e+04, 4.90490000e+04,
#         3.78960000e+04, 4.83910000e+04, 1.02411000e+05, 8.00180000e+04,
#         8.95700000e+04, 9.98830000e+04, 1.77812000e+05, 1.50451000e+05,
#         2.19750000e+05, 9.93515000e+05, 5.63045970e+07, 1.10244645e+08,
#         5.41193310e+08, 3.43842646e+08, 6.63337790e+07, 1.39836268e+08,
#         2.64037210e+07, 3.94328900e+06, 1.77037000e+05, 7.01160000e+04,
#         4.98750000e+04, 2.13580000e+04, 2.52900000e+03, 1.64900000e+03,
#         1.17700000e+03, 1.11300000e+03, 5.27000000e+02, 4.41000000e+02,
#         4.99000000e+02, 2.88000000e+02, 2.29000000e+02, 2.02000000e+02,
#         2.74000000e+02, 1.50000000e+02, 1.26000000e+02, 1.16000000e+02,
#         1.50000000e+02, 9.60000000e+01, 8.40000000e+01, 1.15000000e+02,
# ...
