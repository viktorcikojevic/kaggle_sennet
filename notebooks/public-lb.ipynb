# %%
import pandas as pd

file = "/home/viktor/Documents/kaggle/kaggle_sennet/notebooks/public-lb/blood-vessel-segmentation-publicleaderboard-2024-02-05T10:40:15.csv"

df = pd.read_csv(file)
df
# Out:
#       Rank    TeamId          TeamName   LastSubmissionDate  Score  \
# 0        1  11283300           Clevert  2024-02-03 13:06:34  0.898
# 1        2  11444543            tanxxx  2024-02-04 13:46:49  0.895
# 2        3  11372621           Team LP  2024-02-04 23:50:28  0.894
# 3        4  11362156       martiroshot  2024-02-05 00:19:39  0.894
# 4        5  11210558    Igor Krashenyi  2024-02-04 19:15:50  0.892
# ...    ...       ...               ...                  ...    ...
# 1144  1144  11472013     Leonid Didukh  2024-02-04 20:54:26  0.000
# 1145  1145  11418838     Tsutomu.Azuma  2024-02-05 08:17:49  0.000
# 1146  1146  11487314        Dysvalence  2024-02-05 01:29:12  0.000
# 1147  1147  11484418   Jay Yanamandala  2024-02-05 01:19:01  0.000
# 1148  1148  11460213  Shrajan Bhandary  2024-02-05 10:01:50  0.000
#
#       SubmissionCount           TeamMemberUserNames
# 0                 273              clevert,lum0s517
# 1                 146                        tanxxx
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(df['Score'], bins=50, range=(0.8, 1));

# %%
import numpy as np

np.sum(df['Score']>0.88) / len(df)
# Out:
# 0.011314186248912098
