# %%
import sys


sys.path.append("../src/")

# %%
from sennet.core.mmap_arrays import read_mmap_array
import matplotlib.pyplot as plt

# %%
mmap = read_mmap_array("/home/clay/research/kaggle/sennet/data_dumps/predicted/ensembled/kidney_3_dense/chunk_00/mean_prob")

# %%
plt.imshow(mmap.data[100, ...], vmin=0, vmax=1)

# %%
plt.imshow(mmap.data[200, ...], vmin=0, vmax=1)
