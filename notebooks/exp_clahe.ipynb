# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/opt/kaggle/sennet/data/blood-vessel-segmentation/train/kidney_1_voi/images/0034.tif", 0)
img = img[::8, ::8]
plt.imshow(img)

# %%
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
clahe_out = clahe.apply(img)
plt.imshow(clahe_out)
