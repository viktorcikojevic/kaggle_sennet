# %%
import pandas as pd 
import wandb
api = wandb.Api()

# Project is specified by <entity/project-name>
runs = api.runs("viktor-cikojevic/three_d_seg")

summary_list, config_list, name_list = [], [], []
for run in runs: 
    # .summary contains the output keys/values for metrics like accuracy.
    #  We call ._json_dict to omit large files 
    summary_list.append(run.summary._json_dict)

    # .config contains the hyperparameters.
    #  We remove special values that start with _.
    config_list.append(
        {k: v for k,v in run.config.items()
          if not k.startswith('_')})

    # .name is the human-readable name of the run.
    name_list.append(run.name)

df = pd.DataFrame({
    "summary": summary_list,
    "config": config_list,
    "name": name_list
    })

# %%
df.head()
# Out:
#                                              summary  \
# 0  {'threshold': 0.019999999552965164, 'surface_d...
# 1  {'_wandb': {'runtime': 3734}, 'lr-AdamW': 0.00...
# 2  {'threshold': 0.009999999776482582, 'train_los...
# 3  {'crude_f1': 0, 'surface_dice': 0.848425626754...
# 4  {'_step': 2082, 'epoch': 1, 'lr-AdamW': 0.0003...
#
#                                               config  \
# 0  {'loss': [{'type': 'BCELoss', 'weight': 0.001}...
# 1  {'loss': [{'type': 'BCELoss', 'weight': 0.001}...
# 2  {'loss': [{'type': 'BCELoss', 'weight': 0.001}...
# 3  {'loss': [{'type': 'BCELoss', 'weight': 0.001}...
# 4  {'loss': [{'type': 'BCELoss', 'weight': 0.001}...
#
#                                                 name
# 0  SMP(Unet_resnet50_imagenet)-c512x1-bs32-llr-3....
# 1  SMP(Unet_resnet50_imagenet)-c512x1-bs32-llr-3....
# 2  SMP(Unet_resnet50_imagenet)-c640x1-bs32-llr-3....
# 3  SMP(Unet_resnet50_imagenet)-c576x1-bs32-llr-3....
# 4  SMP(Unet_resnet50_imagenet)-c640x1-bs32-llr-3....

# %%
group_names = []
for i in range(len(df)):
    try:
        group_name = df.config.iloc[i]['group_name']
        group_names.append(group_name)
    except:
        group_names.append('None')
    
df['group_name'] = group_names

# %%
df = df[df['group_name'] == 'smp_unet_r50_scan_crop_size_n_channels'].reset_index(drop=True)
df
# Out:
#                                               summary  \
# 0   {'_wandb': {'runtime': 3734}, 'lr-AdamW': 0.00...
# 1   {'threshold': 0.009999999776482582, 'train_los...
# 2   {'crude_f1': 0, 'surface_dice': 0.848425626754...
# 3   {'_step': 2082, 'epoch': 1, 'lr-AdamW': 0.0003...
# 4   {'surface_dice': 0.8612644672393799, 'crude_f1...
# 5   {'_wandb': {'runtime': 7308}, 'threshold': 0.0...
# 6   {'_wandb': {'runtime': 4059}, '_runtime': 4060...
# 7   {'crude_f1': 0, '_timestamp': 1703876718.64969...
# 8   {'crude_val_loss': 0, '_wandb': {'runtime': 51...
# 9   {'_step': 1757, 'trainer/global_step': 17499, ...
# 10  {'epoch': 0, 'crude_f1': 0, 'f1_score': 0.9212...
# 11  {'_step': 3522, 'crude_f1': 0, 'f1_score': 0.9...
# 12  {'train_loss': 0.06576887518167496, 'f1_score'...
# 13  {'lr-AdamW': 0.00031622776601683794, '_wandb':...
#
#                                                config  \
# 0   {'loss': [{'type': 'BCELoss', 'weight': 0.001}...
# 1   {'loss': [{'type': 'BCELoss', 'weight': 0.001}...
# 2   {'loss': [{'type': 'BCELoss', 'weight': 0.001}...
# 3   {'loss': [{'type': 'BCELoss', 'weight': 0.001}...
# 4   {'loss': [{'type': 'BCELoss', 'weight': 0.001}...
# 5   {'loss': [{'type': 'BCELoss', 'weight': 0.001}...
# 6   {'loss': [{'type': 'BCELoss', 'weight': 0.001}...
# 7   {'loss': [{'type': 'BCELoss', 'weight': 0.001}...
# 8   {'loss': [{'type': 'BCELoss', 'weight': 0.001}...
# 9   {'loss': [{'type': 'BCELoss', 'weight': 0.001}...
# 10  {'loss': [{'type': 'BCELoss', 'weight': 0.001}...
# 11  {'loss': [{'type': 'BCELoss', 'weight': 0.001}...
# 12  {'loss': [{'type': 'BCELoss', 'weight': 0.001}...
# 13  {'loss': [{'type': 'BCELoss', 'weight': 0.001}...
#
#                                                  name  \
# 0   SMP(Unet_resnet50_imagenet)-c512x1-bs32-llr-3....
# 1   SMP(Unet_resnet50_imagenet)-c640x1-bs32-llr-3....
# 2   SMP(Unet_resnet50_imagenet)-c576x1-bs32-llr-3....
# 3   SMP(Unet_resnet50_imagenet)-c640x1-bs32-llr-3....
# 4   SMP(Unet_resnet50_imagenet)-c576x1-bs32-llr-3....
# 5   SMP(Unet_resnet50_imagenet)-c384x4-bs32-llr-3....
# 6   SMP(Unet_resnet50_imagenet)-c384x3-bs32-llr-3....
# 7   SMP(Unet_resnet50_imagenet)-c384x2-bs32-llr-3....
# 8   SMP(Unet_resnet50_imagenet)-c512x1-bs32-llr-3....
# 9   SMP(Unet_resnet50_imagenet)-c384x1-bs32-llr-3....
# 10  SMP(Unet_resnet50_imagenet)-c256x1-bs32-llr-3....
# 11  SMP(Unet_resnet50_imagenet)-c64x1-bs32-llr-3.5...
# 12  SMP(Unet_resnet50_imagenet)-c192x3-bs32-llr-3....
# 13  SMP(Unet_resnet50_imagenet)-c192x1-bs32-llr-3....
#
#                                 group_name
# 0   smp_unet_r50_scan_crop_size_n_channels
# 1   smp_unet_r50_scan_crop_size_n_channels
# 2   smp_unet_r50_scan_crop_size_n_channels
# 3   smp_unet_r50_scan_crop_size_n_channels
# 4   smp_unet_r50_scan_crop_size_n_channels
# 5   smp_unet_r50_scan_crop_size_n_channels
# 6   smp_unet_r50_scan_crop_size_n_channels
# 7   smp_unet_r50_scan_crop_size_n_channels
# 8   smp_unet_r50_scan_crop_size_n_channels
# 9   smp_unet_r50_scan_crop_size_n_channels
# 10  smp_unet_r50_scan_crop_size_n_channels
# 11  smp_unet_r50_scan_crop_size_n_channels
# 12  smp_unet_r50_scan_crop_size_n_channels
# 13  smp_unet_r50_scan_crop_size_n_channels

# %%
def flatten_dict(d, parent_key='', sep='_'):
    items = []
    if not isinstance(d, (dict, list)):
        # Return immediately if d is neither a dictionary nor a list
        return {parent_key: d}

    for k, v in d.items() if isinstance(d, dict) else enumerate(d):
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_dict(v, new_key, sep=sep).items())
        elif isinstance(v, list):
            for i, item in enumerate(v):
                items.extend(flatten_dict(item, f"{new_key}{sep}{i}", sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# %%
flat_configs = []
# loop over rows
for indx_row, row in df.iterrows():
    # Flatten the config   
    config = row['config']
    flat_config = flatten_dict(config)
    flat_configs.append(flat_config)

# %%
df = pd.DataFrame(flat_configs)
df.head()
# Out:
#   loss_0_type  loss_0_weight loss_1_type  loss_1_weight loss_2_type  \
# 0     BCELoss          0.001     MccLoss          0.001    DiceLoss
# 1     BCELoss          0.001     MccLoss          0.001    DiceLoss
# 2     BCELoss          0.001     MccLoss          0.001    DiceLoss
# 3     BCELoss          0.001     MccLoss          0.001    DiceLoss
# 4     BCELoss          0.001     MccLoss          0.001    DiceLoss
#
#    loss_2_kwargs_smooth  loss_2_weight loss_3_type  loss_3_kwargs_gamma  \
# 0                0.0001            0.4   FocalLoss                    2
# 1                0.0001            0.4   FocalLoss                    2
# 2                0.0001            0.4   FocalLoss                    2
# 3                0.0001            0.4   FocalLoss                    2
# 4                0.0001            0.4   FocalLoss                    2
#
#    loss_3_weight  ...  early_stopping_min_delta  \
# 0            0.6  ...                         0
# 1            0.6  ...                         0
# 2            0.6  ...                         0
# 3            0.6  ...                         0
# 4            0.6  ...                         0
#
#    batch_transform_kwargs_mixup_prob  batch_transform_kwargs_alpha_mixup  \
# 0                                  0                                 0.4
# 1                                  0                                 0.4
# 2                                  0                                 0.4
# 3                                  0                                 0.4
# 4                                  0                                 0.4
#
#   batch_transform_kwargs_cutmix_prob  batch_transform_kwargs_alpha_cutmix  \
# 0                                0.3                                  0.4
# 1                                0.3                                  0.4
# 2                                0.3                                  0.4
# 3                                0.3                                  0.4
# 4                                0.3                                  0.4
#
#                                      experiment_name  quit_immediately  \
# 0  SMP(Unet_resnet50_imagenet)-c512x1-bs32-llr-3....             False
# 1  SMP(Unet_resnet50_imagenet)-c640x1-bs32-llr-3....             False
# 2  SMP(Unet_resnet50_imagenet)-c576x1-bs32-llr-3....             False
# 3  SMP(Unet_resnet50_imagenet)-c640x1-bs32-llr-3....             False
# 4  SMP(Unet_resnet50_imagenet)-c576x1-bs32-llr-3....             False
#
#   best_surface_dice val_check_interval  apparent_batch_size
# 0          0.888774              40000                   16
# 1          0.885396              40000                   16
# 2          0.876694              40000                   16
# 3          0.883585              40000                   16
# 4          0.884713              40000                   16
#
# [5 rows x 90 columns]

# %%
df = df[['dataset_kwargs_crop_size', 'dataset_kwargs_n_take_channels', 'best_surface_dice']]
# rename columns
df.columns = ['crop_size', 'n_take_channels', 'best_surface_dice']
# drop nan
df = df.dropna().reset_index(drop=True)

df
# Out:
#     crop_size  n_take_channels  best_surface_dice
# 0         512                1           0.888774
# 1         640                1           0.885396
# 2         576                1           0.876694
# 3         640                1           0.883585
# 4         576                1           0.884713
# 5         384                4           0.881508
# 6         384                3           0.876686
# 7         384                2           0.882567
# 8         512                1           0.877321
# 9         384                1           0.885373
# 10        256                1           0.881221
# 11         64                1           0.848643
# 12        192                3           0.873458
# 13        192                1           0.872801

# %%
import matplotlib.pyplot as plt

plt.scatter(df['crop_size'], df['best_surface_dice'])

plt.xlabel('crop_size')
plt.ylabel('best_surface_dice')
# Out:
# Text(0, 0.5, 'best_surface_dice')

# %%
df['best_surface_dice']
# Out:
# 0     0.888774
# 1     0.885396
# 2     0.876694
# 3     0.883585
# 4     0.884713
# 5     0.881508
# 6     0.876686
# 7     0.882567
# 8     0.877321
# 9     0.885373
# 10    0.881221
# 11    0.848643
# 12    0.873458
# 13    0.872801
# Name: best_surface_dice, dtype: float64

# %%
df = df[df['crop_size'] == 384].reset_index(drop=True)


plt.scatter(df['n_take_channels'], df['best_surface_dice'])

plt.xlabel('n_take_channels')
plt.ylabel('best_surface_dice')
# Out:
# Text(0, 0.5, 'best_surface_dice')
